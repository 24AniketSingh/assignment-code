# %%
import tabula
file1=tabula.read_pdf("100100502_AES01267KY_ORG_Financial-Statement_2020.pdf",pages="5",stream=True)[0]
file2=tabula.read_pdf("100100502_AES01267KY_ORG_Financial-Statement_2020.pdf",pages="4",stream=True)[0]
tabula.convert_into("100100502_AES01267KY_ORG_Financial-Statement_2020.pdf", "profit loss sheet.csv", output_format="csv", pages='5',stream=True)
tabula.convert_into("100100502_AES01267KY_ORG_Financial-Statement_2020.pdf", "consolidated balance sheet.csv", output_format="csv", pages='4',stream=True)
print(file1)
print(file2)
# Out:
#                                           PArtICuLArs  notes       Year ended  \
# 0                                                 NaN    NaN  31st March 2020
# 1                                              InCoMe    NaN              NaN
# 2                             Revenue from Operations   30.0        13,748.19
# 3                                        Other Income   31.0           103.98
# 4                                        total Income    NaN        13,852.17
# 5                                            exPenses    NaN              NaN
# 6                      Cost of Raw Materials Consumed   32.0         8,078.77
# 7                         Purchases of Stock-in Trade   33.0           712.02
# 8   Changes in Inventories of Finished Goods, Work...   34.0            41.91
# 9                           Employee Benefits Expense   35.0           871.27
# 10                                      Finance Costs   36.0           190.26
# 11              Depreciation and Amortisation expense   37.0           278.20
# 12                                     Other Expenses   38.0         2,667.55
# 13                                     total expenses    NaN        12,839.98
# 14                                  Profit Before tax    NaN         1,012.19
# 15                                       tax expenses   42.0              NaN
# 16                                        Current Tax    NaN           279.51
# 17                                       Deferred Tax    NaN         (133.49)
# 18                                  total tax expense    NaN           146.02
# 19  Profit for the year Before share of Loss of As...    NaN           866.17
# 20                Less : Share of (Loss) of Associate    NaN                -
# 21                                Profit for the Year    NaN           866.17
# 22                other Comprehensive Income / (Loss)    NaN              NaN
# 23  Items that will not be reclassified to profit ...    NaN              NaN
# 24        Remeasurements of the defined benefit plans    NaN            20.65
# 25  Income Tax relating to items that will not be ...    NaN           (5.31)
# 26                          Share of OCI in associate    NaN                -
# 27                                                NaN    NaN            15.34
# 28     Items that will reclassified to profit or loss    NaN              NaN
# 29  Exchange differences in translating the financ...    NaN          (17.94)
# 30                                                NaN    NaN          (17.94)
# 31  other Comprehensive Income/(Loss) for the Year...    NaN           (2.60)
# 32            total Comprehensive Income for the Year    NaN           863.57
# 33               Profit for the Year Attributable to:    NaN              NaN
# 34                              Owners of the Company    NaN           876.30
# 35                           Non-controlling interest    NaN          (10.13)
# 36                                                NaN    NaN           866.17
# 37  other Comprehensive Income/(Loss) for the Year...    NaN              NaN
# 38                              Owners of the Company    NaN             0.93
# 39                           Non-controlling interest    NaN           (3.53)
# 40                                                NaN    NaN           (2.60)
# 41  total Comprehensive Income for the Year Attrib...    NaN              NaN
# 42                              Owners of the Company    NaN           877.23
# 43                           Non-controlling interest    NaN          (13.66)
# 44                                                NaN    NaN           863.57
# 45      Earnings per equity share (Face value of ` 2)   45.0              NaN
# 46                                       Basic (in `)    NaN             7.16
# 47                                     Diluted (in `)    NaN             7.16
#
#        Year ended.1
# 0   31st March 2019
# 1               NaN
# 2         14,235.02
# 3            133.52
# 4         14,368.54
# 5               NaN
# 6          9,465.64
# 7            159.88
# 8          (765.04)
# 9            636.79
# 10            90.75
# 11           212.49
# 12         2,376.33
# 13        12,176.84
# 14         2,191.70
# 15              NaN
# 16           618.77
# 17           151.10
# 18           769.87
# 19         1,421.83
# 20           (8.84)
# 21         1,412.99
# 22              NaN
# 23              NaN
# 24           (6.70)
# 25             2.34
# 26                -
# 27           (5.36)
# 28              NaN
# 29                -
# 30                -
# 31           (4.36)
# 32         1,408.63
# 33              NaN
# 34         1,431.99
# 35          (19.00)
# 36         1,412.99
# 37              NaN
# 38           (4.36)
# 39                -
# 40           (4.36)
# 41              NaN
# 42         1,427.63
# 43          (19.00)
# 44         1,408.63
# 45              NaN
# 46            11.56
# 47            11.54
#                       Particulars  notes             As at           As at.1
# 0                             NaN    NaN  31st March, 2020  31st March, 2019
# 1                          Assets    NaN               NaN               NaN
# 2          non - Current Assets :    NaN               NaN               NaN
# 3   Property, Plant and Equipment    2.0          6,376.38          6,056.63
# 4        Capital Work-in-progress    NaN             68.58            255.10
# ..                            ...    ...               ...               ...
# 56                     Provisions   28.0                 -             10.13
# 57   Income Tax Liabilities (Net)   29.0             95.94              0.02
# 58      total Current Liabilities    NaN          4,945.13          4,107.49
# 59              total Liabilities    NaN          5,328.48          4,683.72
# 60   total equity and Liabilities    NaN         14,695.47         12,986.58
#
# [61 rows x 4 columns]
